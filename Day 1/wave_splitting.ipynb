# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
#!/usr/bin/env python
## Import
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading the data

# %%
# The csv files in data are organized in columns
# t, P, Q, A with seperator ';'
data_file = 'data/bifurcation_F_5.csv'
data = np.genfromtxt(data_file, delimiter=';', skip_header=1)
t = data[:,0]
P = data[:,1]
Q = data[:,2]

# An alternative is Pandas which allows access by column name, though the 
# units are a bit annoying here. It can be good for more advanced data wrangling.
pd.read_csv(data_file, sep=';') # For your future usage
# Out:
#         t [s]        P [Pa]     Q [m^3/s]   A [m^2]
# 0    0.000000  13332.000000  0.000000e+00  0.002951
# 1    0.003311  13332.555960  5.388482e-07  0.002951
# 2    0.006623  13334.217296  2.149329e-06  0.002951
# 3    0.009934  13336.965337  4.813863e-06  0.002952
# 4    0.013245  13340.769227  8.503198e-06  0.002953
# 5    0.016556  13345.586324  1.317673e-05  0.002955
# 6    0.019868  13351.362883  1.878286e-05  0.002957
# 7    0.023179  13358.034603  2.525969e-05  0.002959
# 8    0.026490  13365.527428  3.253579e-05  0.002962
# 9    0.029801  13373.758411  4.053106e-05  0.002965
# 10   0.033113  13382.636786  4.915757e-05  0.002967
# 11   0.036424  13392.065054  5.832062e-05  0.002971
# 12   0.039735  13401.940152  6.791978e-05  0.002974
# 13   0.043046  13412.154622  7.785003e-05  0.002977
# 14   0.046358  13422.597843  8.800298e-05  0.002981
# 15   0.049669  13433.157265  9.826805e-05  0.002984
# 16   0.052980  13443.719652  1.085337e-04  0.002988
# 17   0.056291  13454.172306  1.186885e-04  0.002992
# 18   0.059603  13464.404260  1.286227e-04  0.002995
# 19   0.062914  13474.307427  1.382290e-04  0.002998
# 20   0.066225  13483.777696  1.474038e-04  0.003001
# 21   0.069536  13492.715981  1.560485e-04  0.003004
# 22   0.072848  13501.029181  1.640702e-04  0.003007
# 23   0.076159  13508.631082  1.713828e-04  0.003010
# 24   0.079470  13515.443169  1.779082e-04  0.003012
# 25   0.082781  13521.395355  1.835765e-04  0.003014
# 26   0.086093  13526.426623  1.883272e-04  0.003016
# 27   0.089404  13530.485576  1.921095e-04  0.003017
# 28   0.092715  13533.530900  1.948831e-04  0.003018
# 29   0.096026  13535.531727  1.966183e-04  0.003019
# ..        ...           ...           ...       ...
# 272  0.900662  13332.630649 -1.385315e-07  0.002951
# 273  0.903974  13332.635387 -1.431231e-07  0.002951
# 274  0.907285  13332.636806 -1.444990e-07  0.002951
# 275  0.910596  13332.636181 -1.438933e-07  0.002951
# 276  0.913907  13332.634590 -1.423515e-07  0.002951
# 277  0.917219  13332.632846 -1.406605e-07  0.002951
# 278  0.920530  13332.631453 -1.393100e-07  0.002951
# 279  0.923841  13332.630616 -1.384989e-07  0.002951
# 280  0.927152  13332.630298 -1.381906e-07  0.002951
# 281  0.930464  13332.630316 -1.382083e-07  0.002951
# 282  0.933775  13332.630453 -1.383407e-07  0.002951
# 283  0.937086  13332.630544 -1.384290e-07  0.002951
# 284  0.940397  13332.630520 -1.384060e-07  0.002951
# 285  0.943709  13332.630396 -1.382859e-07  0.002951
# 286  0.947020  13332.630228 -1.381233e-07  0.002951
# 287  0.950331  13332.630069 -1.379692e-07  0.002951
# 288  0.953642  13332.629943 -1.378464e-07  0.002951
# 289  0.956954  13332.629844 -1.377509e-07  0.002951
# 290  0.960265  13332.629757 -1.376666e-07  0.002951
# 291  0.963576  13332.629669 -1.375808e-07  0.002951
# 292  0.966887  13332.629575 -1.374902e-07  0.002951
# 293  0.970199  13332.629480 -1.373979e-07  0.002951
# 294  0.973510  13332.629387 -1.373080e-07  0.002951
# 295  0.976821  13332.629299 -1.372224e-07  0.002951
# 296  0.980132  13332.629214 -1.371405e-07  0.002951
# 297  0.983444  13332.629132 -1.370611e-07  0.002951
# 298  0.986755  13332.629052 -1.369835e-07  0.002951
# 299  0.990066  13332.628974 -1.369080e-07  0.002951
# 300  0.993377  13332.628899 -1.368347e-07  0.002951
# 301  0.996689  13332.628826 -1.367639e-07  0.002951
#
# [302 rows x 4 columns]

# %% [markdown]
# # Basic plotting

# %%
plt.plot(t, P, label='data') # add a label for the legend
plt.xlabel('time')
plt.ylabel('Pressure')
plt.legend() # Make the legend appear
# Out:
# <img src="data:image/png;base64,..." width="639.9833333333333">

# %% [markdown]
# # Bifurcation with clearly seperated waves

# %%
data_file = 'data/bifurcation_F_5.csv'

# %% [markdown]
# # Bifurcation with mixed  waves

# %%
data_file = 'data/bifurcation_F_1-5.csv'

# %% [markdown]
# # Full network with compliant arteries

# %%
data_file = 'data/55arteryNetwork_age19.csv'

# %% [markdown]
# # Full network with stiff arteries

# %%
data_file = 'data/55arteryNetwork_age75.csv'
